# %%
import pandas as pd

# %%
file_path='D:\深圳杯\代码\附件2 慢性病及相关因素流调数据.xlsx'
data=pd.read_excel(file_path)
data.head()
# Out:
#    Q1-ID  Q2-出生年  Q3-性别  Q4-民族 Q5-民族_其他  Q6-文化程度  Q7-婚姻状况  Q8-职业  Q9-是否吸烟  \
# 0  10001    1983      2      1      NaN        4      1.0    9.0      3.0
# 1  10002    1994      2      1      NaN        3      1.0   13.0      3.0
# 2  10003    1976      1      1      NaN        4      2.0    4.0      1.0
# 3  10004    1984      1      1      NaN        5      2.0   12.0      3.0
# 4  10005    1968      1      1      NaN        4      2.0    9.0      1.0
#
#    Q10-开始吸烟年龄  ...  Q225-臀围  Q226-收缩压  Q227-舒张压  Q228-脉搏  Q229-胆固醇  Q230-血糖  \
# 0         NaN  ...     92.0      98.0      62.0     70.0      3.79     4.61
# 1         NaN  ...     88.0     104.0      70.0     80.0      4.24     4.59
# 2        16.0  ...     95.0     104.0      70.0     80.0      4.84     4.13
# 3         NaN  ...    106.0     126.0      82.0     72.0      5.20     4.68
# 4        20.0  ...     97.0     106.0      70.0     70.0      5.10     4.41
#
#    Q231-高密度脂蛋白  Q232-低密度脂蛋白  Q233-甘油三酯  Q234-尿酸
# ...

# %%
data.columns
# Out:
# Index(['Q1-ID', 'Q2-出生年', 'Q3-性别', 'Q4-民族', 'Q5-民族_其他', 'Q6-文化程度', 'Q7-婚姻状况',
#        'Q8-职业', 'Q9-是否吸烟', 'Q10-开始吸烟年龄',
#        ...
#        'Q225-臀围', 'Q226-收缩压', 'Q227-舒张压', 'Q228-脉搏', 'Q229-胆固醇', 'Q230-血糖',
#        'Q231-高密度脂蛋白', 'Q232-低密度脂蛋白', 'Q233-甘油三酯', 'Q234-尿酸'],
#       dtype='object', length=234)

# %%
df1=pd.DataFrame(data['Q1-ID'])

# %% [markdown]
# ![image.png](attachment:1532b9fe-d3c7-4a1b-98c5-e3ab514b1be5.png)

# %%
a='''Q54-食用大米的频率（次数/天）
Q59-食用小麦面粉的频率（次数/天）
Q64-食用杂粮的频率
Q69-食用薯类的频率
Q74-食用油炸面食的频率
Q169-食用糕点的频率
'''
df1['谷薯类每天食用次数']=data[a.split()].sum(axis=1)

a='''（次数/周）
（次数/周）.1
（次数/周）.2
（次数/周）.3
（次数/周）.4
（次数/周）.23
'''
df1['谷薯类每天食用次数（周/7）']=data[a.split()].sum(axis=1)/7

# %%
df1
# Out:
#       Q1-ID  谷薯类每天食用次数  谷薯类每天食用次数（周/7）
# 0     10001        1.0        0.285714
# 1     10002        2.0        0.571429
# 2     10003        2.0        0.428571
# 3     10004        3.0        0.714286
# 4     10005        1.0        0.285714
# ...     ...        ...             ...
# 7704  17705        2.0        0.000000
# 7705  17706        2.0        0.000000
# 7706  17707        2.0        0.285714
# 7707  17708        3.0        0.000000
# 7708  17709        3.0        0.000000
#
# [7709 rows x 3 columns]

# %%
a='''Q79-食用猪肉的频率
Q84-食用牛羊肉的频率
Q89-食用禽肉的频率
Q94-食用内脏的频率
Q99-食用水产的频率
Q104-食用鲜奶的频率
Q109-食用奶粉的频率
Q114-食用酸奶的频率
Q119-食用蛋类的频率
'''
df1['畜禽鱼蛋奶']=data[a.split()].sum(axis=1)

a='''（次数/周）.5
（次数/周）.6
（次数/周）.7
（次数/周）.8
（次数/周）.9
（次数/周）.10
（次数/周）.11
（次数/周）.12
（次数/周）.13
'''
df1['畜禽鱼蛋奶（周/7）']=data[a.split()].sum(axis=1)/7

# %%
a='''Q124-食用豆腐的频率
Q129-食用豆腐丝等的频率
Q134-食用豆浆的频率
Q139-食用干豆的频率
'''
df1['豆类食物']=data[a.split()].sum(axis=1)



a='''（次数/周）.14
（次数/周）.15
（次数/周）.16
（次数/周）.17
'''
df1['豆类食物（周/7）']=data[a.split()].sum(axis=1)/7

# %%
a='''Q144-食用新鲜蔬菜的频率
Q149-食用海草的频率
Q154-食用咸菜的频率
Q159-食用泡菜的频率
Q164-食用酸菜的频率
Q174-食用水果的频率
Q179-食用果汁饮料的频率
Q184-食用其他饮料的频率
'''
df1['蔬菜水果']=data[a.split()].sum(axis=1)

a='''（次数/周）.18
（次数/周）.19
（次数/周）.20
（次数/周）.21
（次数/周）.22
（次数/周）.24
（次数/周）.25
（次数/周）.26
'''
df1['蔬菜水果（周/7）']=data[a.split()].sum(axis=1)/7

# %%
df1
# Out:
#       Q1-ID  谷薯类每天食用次数  谷薯类每天食用次数（周/7）  畜禽鱼蛋奶  畜禽鱼蛋奶（周/7）  豆类食物  豆类食物（周/7）  \
# 0     10001        1.0        0.285714    2.0    0.714286   0.0   0.285714
# 1     10002        2.0        0.571429    4.0    0.714286   0.0   0.428571
# 2     10003        2.0        0.428571    2.0    0.714286   0.0   0.000000
# 3     10004        3.0        0.714286    5.0    0.571429   0.0   1.142857
# 4     10005        1.0        0.285714    0.0    1.285714   0.0   0.000000
# ...     ...        ...             ...    ...         ...   ...        ...
# 7704  17705        2.0        0.000000    1.0    0.857143   0.0   0.000000
# 7705  17706        2.0        0.000000    1.0    0.857143   0.0   0.428571
# 7706  17707        2.0        0.285714    2.0    0.714286   0.0   0.571429
# 7707  17708        3.0        0.000000    4.0    0.428571   0.0   0.000000
# 7708  17709        3.0        0.000000    4.0    0.285714   0.0   0.000000
#
#       蔬菜水果  蔬菜水果（周/7）
# 0      4.0   0.142857
# ...

# %%
a='''Q54-食用大米的频率（次数/天）
Q59-食用小麦面粉的频率（次数/天）
Q64-食用杂粮的频率
Q69-食用薯类的频率
Q74-食用油炸面食的频率
Q79-食用猪肉的频率
Q84-食用牛羊肉的频率
Q89-食用禽肉的频率
Q94-食用内脏的频率
Q99-食用水产的频率
Q104-食用鲜奶的频率
Q109-食用奶粉的频率
Q114-食用酸奶的频率
Q119-食用蛋类的频率
Q124-食用豆腐的频率
Q129-食用豆腐丝等的频率
Q134-食用豆浆的频率
Q139-食用干豆的频率
Q144-食用新鲜蔬菜的频率
Q149-食用海草的频率
Q154-食用咸菜的频率
Q159-食用泡菜的频率
Q164-食用酸菜的频率
Q169-食用糕点的频率
Q174-食用水果的频率
Q179-食用果汁饮料的频率
Q184-食用其他饮料的频率
'''
df1['每天摄入食物类型数量']=data[a.split()].count(axis=1)

# %%
a='''（次数/周）
（次数/周）.1
（次数/周）.2
（次数/周）.3
（次数/周）.4
（次数/周）.5
（次数/周）.6
（次数/周）.7
（次数/周）.8
（次数/周）.9
（次数/周）.10
（次数/周）.11
（次数/周）.12
（次数/周）.13
（次数/周）.14
（次数/周）.15
（次数/周）.16
（次数/周）.17
（次数/周）.18
（次数/周）.19
（次数/周）.20
（次数/周）.21
（次数/周）.22
（次数/周）.23
（次数/周）.24
（次数/周）.25
（次数/周）.26
'''
df1['每周摄入食物类型数量']=data[a.split()].count(axis=1)

# %%
import pandas as pd

def sigma(series_data):  
    # 计算数据的均值和标准差
    mean_val = series_data.mean()
    std_dev = series_data.std()

    # 定义异常值的阈值范围
    threshold = 3 * std_dev

    # 进行3σ异常值清洗
    return series_data[series_data.between(mean_val - threshold, mean_val + threshold)]

# %%
# BMI(公斤体重/身高米的平方)
# 计算BMI值
df1['BMI'] = data['Q223-体重'] / ((data['Q222-身高']/100) ** 2)

# %%
i='BMI'
sns.distplot(sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1['BMI']
# 划分 'BMI' 列为不同层级
bins = [0, 18.5, 24.9, 29.9, float('inf')]
labels = ['过瘦', '正常体重', '超重', '肥胖']

df1['BMI_Category']= pd.cut(df1['BMI'], bins=bins, labels=labels)

# 使用Seaborn绘制可视化图形
sns.countplot(x='BMI_Category', data=df1, palette='viridis')

# 添加标题和标签
plt.title('BMI 分层 ')
plt.xlabel('BMI 分层')
plt.ylabel('Count')
plt.savefig('./Q1/BMI分层')
# 显示图形
plt.show()

# %%
import numpy as np
df1['每周参加体育锻炼频率']=data['Q197-是否参加体育锻炼'].map(
{1:'不参加',
2:'1-2 天/周 ',
3:'3-5 天/周 ',
4:'＞5 天/周'}
)

df1['平均每天体育锻炼时间']=data['Q199-平均每天体育锻炼时间'].apply(lambda x:0 if np.isnan(x)==True else x)

# %%
# 使用Seaborn绘制可视化图形  deep, muted, pastel, bright, dark, colorblind
sns.countplot(x='每周参加体育锻炼频率', data=df1, palette='colorblind')

# 添加标题和标签
plt.title('每周参加体育锻炼频率')
plt.xlabel('每周参加体育锻炼频率')
plt.ylabel('Count')
plt.savefig('./Q1/每周参加体育锻炼频率')
# 显示图形
plt.show()

# %%
i='平均每天体育锻炼时间'
sns.distplot(sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1[i].describe()
# Out:
# count    7709.000000
# mean       26.754183
# std        34.588082
# min         0.000000
# 25%         0.000000
# 50%        15.000000
# 75%        40.000000
# max       400.000000
# Name: 平均每天体育锻炼时间, dtype: float64

# %%
df1.columns
# Out:
# Index(['Q1-ID', '谷薯类每天食用次数', '谷薯类每天食用次数（周/7）', '畜禽鱼蛋奶', '畜禽鱼蛋奶（周/7）', '豆类食物',
#        '豆类食物（周/7）', '蔬菜水果', '蔬菜水果（周/7）', '每天摄入食物类型数量', '每周摄入食物类型数量', 'BMI',
#        'BMI_Category', '每周参加体育锻炼频率', '平均每天体育锻炼时间'],
#       dtype='object')

# %%
a='''Q54-食用大米的频率（次数/天）
Q59-食用小麦面粉的频率（次数/天）
Q64-食用杂粮的频率
Q69-食用薯类的频率
Q74-食用油炸面食的频率
Q79-食用猪肉的频率
Q84-食用牛羊肉的频率
Q89-食用禽肉的频率
Q94-食用内脏的频率
Q99-食用水产的频率
Q104-食用鲜奶的频率
Q109-食用奶粉的频率
Q114-食用酸奶的频率
Q119-食用蛋类的频率
Q124-食用豆腐的频率
Q129-食用豆腐丝等的频率
Q134-食用豆浆的频率
Q139-食用干豆的频率
Q144-食用新鲜蔬菜的频率
Q149-食用海草的频率
Q154-食用咸菜的频率
Q159-食用泡菜的频率
Q164-食用酸菜的频率
Q169-食用糕点的频率
Q174-食用水果的频率
Q179-食用果汁饮料的频率
Q184-食用其他饮料的频率
'''
df1['每天食用次数总额']=data[a.split()].sum(axis=1)

# %%
a='''Q54-食用大米的频率（次数/天）
Q59-食用小麦面粉的频率（次数/天）
Q64-食用杂粮的频率
Q74-食用油炸面食的频率
Q104-食用鲜奶的频率
Q109-食用奶粉的频率
Q114-食用酸奶的频率
Q144-食用新鲜蔬菜的频率
Q149-食用海草的频率
Q154-食用咸菜的频率
Q159-食用泡菜的频率
Q164-食用酸菜的频率
Q174-食用水果的频率
'''
df1['菜水果、全谷物和奶制品占比每天摄入频率比例']=data[a.split()].sum(axis=1)/df1['每天食用次数总额']

# %%
i='菜水果、全谷物和奶制品占比每天摄入频率比例'
sns.distplot(sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1[i].describe()
# Out:
# count    7685.000000
# mean        0.730459
# std         0.147355
# min         0.000000
# 25%         0.636364
# 50%         0.714286
# 75%         0.833333
# max         1.000000
# Name: 菜水果、全谷物和奶制品占比每天摄入频率比例, dtype: float64

# %%
df1['新鲜蔬菜摄入量']=data['Q144-食用新鲜蔬菜的频率']*data['Q147-平均每次食用量.18']*50

# %%
i='新鲜蔬菜摄入量'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1[i].describe()
# Out:
# count    7285.000000
# mean      303.381606
# std       195.424273
# min        10.000000
# 25%       200.000000
# 50%       300.000000
# 75%       400.000000
# max      5000.000000
# Name: 新鲜蔬菜摄入量, dtype: float64

# %%
df1['水果摄入量']=data['Q174-食用水果的频率']*data['Q177-平均每次食用量.24']*50

# %%
i='水果摄入量'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1[i].describe()
# Out:
# count     4479.000000
# mean       208.067649
# std        217.448587
# min          0.000000
# 25%        100.000000
# 50%        150.000000
# 75%        250.000000
# max      10000.000000
# Name: 水果摄入量, dtype: float64

# %%
df1['各种各样的奶制品摄入量']=data['Q104-食用鲜奶的频率']*data['Q107-平均每次食用量.10']*50+data['Q109-食用奶粉的频率']*data['Q112-平均每次食用量.11']*50+data['Q114-食用酸奶的频率']*data['Q117-平均每次食用量.12']*50

# %%
i='各种各样的奶制品摄入量'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1[i].describe()
# Out:
# count      17.000000
# mean      629.705882
# std       470.871767
# min       200.000000
# 25%       375.000000
# 50%       550.000000
# 75%       650.000000
# max      1950.000000
# Name: 各种各样的奶制品摄入量, dtype: float64

# %%
a='''（次数/周）
（次数/周）.1
（次数/周）.2
（次数/周）.4
（次数/周）.14
（次数/周）.15
（次数/周）.16
（次数/周）.17
'''
df1['全谷物和奶制品每周摄入次数']=data[a.split()].sum(axis=1)

# %%
i='全谷物和奶制品每周摄入次数'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1['鱼禽、蛋类和瘦肉每天摄入量']=data['Q79-食用猪肉的频率']*data['Q82-平均每次食用量.5']*50+data['Q84-食用牛羊肉的频率']*data['Q87-平均每次食用量.6']*50+data['Q89-食用禽肉的频率']*data['Q92-平均每次食用量.7']*50+data['Q94-食用内脏的频率']*data['Q97-平均每次食用量.8']*50+data['Q99-食用水产的频率']*data['Q102-平均每次食用量.9']*50+data['Q119-食用蛋类的频率']*data['Q122-平均每次食用量.13']*50

# %%
i='鱼禽、蛋类和瘦肉每天摄入量'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1['每周吃水产品频率']=data['（次数/周）.9']

# %%
df1['每周吃水产品频率'].describe()
# Out:
# count    5104.000000
# mean        2.444749
# std         1.210252
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         9.000000
# Name: 每周吃水产品频率, dtype: float64

# %%
i='每周吃水产品频率'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1['每天吃蛋类个数']=data['Q119-食用蛋类的频率']*data['Q122-平均每次食用量.13']

# %%
df1['每天吃蛋类个数'].describe()
# Out:
# count    1177.000000
# mean        1.217842
# std         0.885621
# min         0.100000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        14.000000
# Name: 每天吃蛋类个数, dtype: float64

# %%
i='每天吃蛋类个数'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
a='''Q79-食用猪肉的频率
Q84-食用牛羊肉的频率
Q89-食用禽肉的频率
Q94-食用内脏的频率
Q99-食用水产的频率
'''
df1['每天食用肉类频率总额']=data[a.split()].sum(axis=1)

# %%
a='''Q99-食用水产的频率
'''
df1['食用水产的频率占比每天食用肉类频率比例']=data[a.split()].sum(axis=1)/df1['每天食用肉类频率总额']

# %%
df1['食用水产的频率占比每天食用肉类频率比例'].describe()
# Out:
# count    6313.000000
# mean        0.097918
# std         0.216598
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: 食用水产的频率占比每天食用肉类频率比例, dtype: float64

# %%
i='食用水产的频率占比每天食用肉类频率比例'
sns.distplot( sigma(df1[i]), color='Pink')
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
plt.xlabel(i)
plt.ylabel('Frequency')
plt.savefig('./Q1/%s'%i.replace('/',''))
    # 显示图形
plt.show()

# %%
df1.to_excel('./Q1/饮食习惯变量汇总.xlsx',index=None)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
 
plt.rcParams['font.sans-serif'] = ['SimHei']  
# Matplotlib中设置字体-黑体，解决Matplotlib中文乱码问题
plt.rcParams['axes.unicode_minus'] = False    
# 解决Matplotlib坐标轴负号'-'显示为方块的问题
sns.set(font='SimHei')                        
# Seaborn中设置字体-黑体，解决Seaborn中文乱码问题

# 使用Seaborn绘制频率分布直方图
#https://jingyan.baidu.com/article/eb9f7b6d61838cc79264e86a.html

for i in df1[df1.columns[1:]]:
    aaa=sigma(df1[i])
    sns.distplot(aaa, color='Pink')
    display(aaa.describe())
    # 添加标题和标签
    # plt.title('每周摄入食物类型数量')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    # 显示图形
    plt.savefig('./Q1/%s'%i.replace('/',''))
    plt.show()
# Out:
# count    7640.000000
# mean        2.300524
# std         0.709371
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: 谷薯类每天食用次数, dtype: float64
# count    7616.000000
# mean        0.517520
# std         0.401444
# min         0.000000
# 25%         0.142857
# 50%         0.428571
# 75%         0.714286
# max         1.714286
# Name: 谷薯类每天食用次数（周/7）, dtype: float64
# count    7626.000000
# mean        1.911880
# std         1.267334
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: 畜禽鱼蛋奶, dtype: float64
# count    7646.000000
# mean        1.111412
# std         0.639800
# min         0.000000
# 25%         0.714286
# 50%         1.000000
# 75%         1.571429
# max         3.142857
# Name: 畜禽鱼蛋奶（周/7）, dtype: float64
# count    7500.000000
# mean        0.089867
# std         0.286010
# min         0.000000
# 25%         0.000000
# ...
